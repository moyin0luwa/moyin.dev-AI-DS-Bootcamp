# %% [markdown]
# # Class 4: Python Practice & Assessment
# moyin.dev – AI & Data Science Bootcamp

# %% [markdown]
# ## Class Objectives
# - Work confidently with Jupyter Notebooks
# - Write basic Python scripts
# - Practice Python hands-on using Google Colab
# - Apply knowledge through a mini project

# %% [markdown]
# ## Working with Jupyter Notebooks
# Jupyter notebooks allow us to combine **code**, **text**, and **outputs** in one place.

# %% [markdown]
# ### Common Notebook Cells
# - **Markdown cells**: for explanations
# - **Code cells**: for running Python

# %%
print('This is a code cell')

# %% [markdown]
# ## Basic Python Scripting
# Python scripts follow a simple flow: input → processing → output

# %%
# Basic variables
x = 10
y = 5
print(x + y)

# %% [markdown]
# ## Hands-on Exercise 1
# Write a script that asks for a user's name and prints a greeting.

# %%
name = input("Enter your name: ")
print("Hello", name)

# %% [markdown]
# ## Hands-on Exercise 2
# Write a script that asks for two numbers and prints their sum.

# %%
a = int(input("First number: "))
b = int(input("Second number: "))
print("Sum:", a + b)

# %% [markdown]
# ## Mini Project: Build a guess game

# %%
secret_number = 7

guess = int(input("Guess the number between 1 and 10: "))

if guess == secret_number:
    print("Correct! You guessed the number 🎉")
elif guess > secret_number:
    print("Too high! Try a smaller number.")
else:
    print("Too low! Try a bigger number.")

# %% [markdown]
# ## Mini Project: Build a Calculator
# Your calculator should:
# - Ask for two numbers
# - Ask for an operation (+, -, *, /)
# - Display the result

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
operation = input("Choose operation (+, -, *, /): ")

if operation == '+':
    print(num1 + num2)
elif operation == '-':
    print(num1 - num2)
elif operation == '*':
    print(num1 * num2)
elif operation == '/':
    print(num1 / num2)
else:
    print("Invalid operation")

# %% [markdown]
# ## Assignment Submission
# - Complete the mini calculator
# - Modify it to handle division by zero
# - Submit before next class
